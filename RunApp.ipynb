# %%
! pip install streamlit -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 16.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 9.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 32.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 2.4 MB/s eta 0:00:00

# %%
! pip install pyngrok

# %%
from pyngrok import ngrok

# %%
#Get your Auth_token @ https://dashboard.ngrok.com/login
ngrok.set_auth_token("2RC0rttyLgg9d7oWGIoOfq6bsAI_2BvwPaw4sUv1NNbgHadWN")

# %%
from pyngrok import ngrok
from google.colab import drive


# !nohup streamlit run app.py --server.port 80 &


url = ngrok.connect() # Start a new ngrok session
print(url)
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/CreditCardDataset
# nohup: appending output to 'nohup.out'
# NgrokTunnel: "https://b814-34-16-149-156.ngrok-free.app" -> "http://localhost:80"
